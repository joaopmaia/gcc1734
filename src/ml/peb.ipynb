# %%
import pandas as pd

df = pd.read_csv("../../data/predict-energy-behavior-of-prosumers-publicleaderboard-2023-11-24T22:33:27.csv")
df.shape
# Out:
# (532, 7)

# %%
df.head(50)
# Out:
#     Rank    TeamId                 TeamName   LastSubmissionDate  Score  \
# 0      1  11183929                       QZ  2023-11-15 16:35:16  64.11
# 1      2  11183911          Farukcan Sağlam  2023-11-24 17:38:50  66.54
# 2      3  11187148                    Devin  2023-11-20 11:12:47  66.80
# 3      4  11181044                   at7459  2023-11-24 09:46:44  67.25
# 4      5  11190171                Uuuuuuuup  2023-11-24 15:58:17  67.71
# 5      6  11216506            yakunwenchina  2023-11-24 01:32:28  68.06
# 6      7  11207148                   Raijin  2023-11-18 14:42:19  68.82
# 7      8  11262143                      Wei  2023-11-24 07:54:04  68.98
# 8      9  11190594                  MikeOMa  2023-11-15 00:40:14  69.09
# 9     10  11269458                   Petras  2023-11-24 09:43:28  69.18
# 10    11  11179779               Ryo Asashi  2023-11-21 13:31:07  69.41
# 11    12  11222334               Jangho Seo  2023-11-15 12:03:44  69.42
# ...
